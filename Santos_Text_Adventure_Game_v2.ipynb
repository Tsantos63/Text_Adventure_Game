# %%
"""
Intro to Python
A1: Text Adventure Game Development
Monday October 24, 2018
Thiago Santos

Version 2.0
"""

"""
    DocString:
    
    Introduction:
    Its 8:20 PM and your Python class is about to finish in 10 minutes, your 
    friends starts messaging you asking for you to stop at Little Lingo for a
    beer or two. What should you do? This game is about making that decision 
    to go home or drink on a weekday when you have plenty of homework 
    to do and learn how to code?. 
    
    Stage 1: Decide whether to home or stop at Little Lingo
    Stage 2: Stop at Lingo 
    Stage 3: Questions 
    Stage 4: Trivia 
    Stage 5: Avalon after party 
    
    
"""

# allows the player to exit the game 
from sys import exit

# essential to generate random questions for the game
import random

def stage_0():
    print(""" 
         Its 8:30 and you're done with your Python class for the day. 
         As you get off the elevator and start making your way across Hult's
         lobby your friends starts to wave at you from little lingo. 
         """)
    input(prompt = "< Press enter to play the game >\n")  
    
    stage_1() 


# stage in the game where the player decides to enter lingo or go home "win" 
def stage_1():
    print("""
    What should you do?
    1) Stop for a beer. 
    2) Go home.

    """)
    
    choice = input(prompt = "Write your response here and press enter > ")
    
    # converting using .casefold
    choice = choice.casefold()

    # conditions 
    if "1" in choice or "stop" in choice or "beer" in choice:
        print("""\nYou are inside Little Lingo now. Let's see how much self control 
        you have.\n""")
        input(prompt = "< Press enter to continue >\n")
        stage_2()
    
    elif "2" in choice or "go" in choice or "home" in choice:
        print("""\nYOU ARE A WINNER! You showed you are very disciplined 
        and chose to go home and enhance your coding skills.
        Congratulations!\n""")
        
        input(prompt = "< Press enter to continue >\n") 
        stage_1()
    
    else:
        print("Invalid command. Please try again.")
        input(prompt = "< Press enter to play the game again >\n") 
        stage_1()
      
    
# this is the stage were you are inside lingo and starts playing trivia games 
def stage_2():
    print("""
    
You greet your friends and your buddy Edwin 
comes towards you with a pitcher and shouts. 
              
              "Answer a question and I will pour you a beer"
        
          """)
    
    # random generated questions 
    question_list = ['What famous beer is made in the Netherlands?',
                     'What year the Red Sox broke the curse of the bambino?',
                     'How many superbowls has Tom Brady won?']
    questions = 3
    
    # loops 
    while questions > 0:
        question = random.choice(question_list)
        input(prompt = "< Press enter to continue >\n")
        print(question)
        print(" ")
        
        if question == question_list[0]:
            print("1) Stella")
            print("2) Heineken")
            print("3) Coors light")
            
            
            beers = input(prompt = "Write your response here and press enter > ") 
            
            # converting using .casefold
            beers = beers.casefold() 
            
            if '3' in beers or 'coors light' in beers: 
                print("WRONG! Just say hi and go home.")
                fail()
                break
            
            elif '2' in beers or 'Heineken' in beers:
                print("CORRECT, take this beer.")
                
                stage_3()
                
            # condition whitin the condition     
            elif '1' in beers or 'Stella' in beers:  
                print("WRONG. Just say hi and go home.")
                
                
                if '2' in beers or 'heineken' in beers: 
                    print("CORRECT. Take this beer.")
                
                    stage_3()
                
                elif '3' in beers or 'coors light' in beers: 
                    print("WRONG! Just say hi and go home.")
                
                    fail()
                    break
                    
                else:
                    print("WRONG. Just say hi and go home.")
                
                    fail()
                    break
        
        elif question == question_list[1]:
            print("1) 2001")
            print("2) 2004")
            print("3) 1998")
            
            year_curse = input(prompt = "Write your response here > ")
            
            if '1'in year_curse or '2000' in year_curse:
                print("WRONG. Just say hi and go home.")
                fail()
                break
            
            elif '2' in year_curse or '2004' in year_curse:
                print("CORRECT. Take this beer.")
                stage_3()
                
            # condition whitin the condition     
            elif '3' in year_curse or '1998' in year_curse:  
                print("ALMOST. give it another try.")
                
                year_curse = input(prompt = "Write your response here and press enter > ")
                
                if '2' in year_curse or '2004' in year_curse: 
                    print("CORRECT. Take this beer.")
                    stage_3()
                
                elif '1' in year_curse or '2001' in year_curse: 
                    print("WRONG. Just say hi and go home.")
                    
                    
                else:
                    print("WRONG. Just say hi and go home.")
                    
                fail()
                break 
                
                

        elif question == question_list[2]:
            print("1) 9")
            print("2) 7")
            print("3) 5") 
            
            superbowls = input(prompt = "Write your response here and press enter> ")
            
            if '9'in superbowls or 'nine' in superbowls:
                print("WRONG. Just say hi and go home.")
                fail()
                break
            
            elif '7' in superbowls or 'seven' in superbowls:
                print("CORRECT. Take this beer.")
                stage_3()
            
            # condition whitin the condition 
            elif '5' in superbowls or 'five' in superbowls:  
                print("ALMOST, give it another try.")
                
                superbowls = input(prompt = "Write your response here and press enter> ")
                
                # extending the conditional 
                if '7' in superbowls or 'seven' in superbowls: 
                    print("CORRECT. Take this beer.")
                    stage_3()
                
                elif '9' in superbowls or 'nine' in superbowls: 
                    print("WRONG. Just say hi and go home.")
                    fail()
                    break

# stage where you decide play another game upon winning the previous or go home
def stage_3():
    print("""
You keep driking. The bartender is playing a short trivia game with people seating at the bar and 
its your turn to answer. You get a 10 dollar gift card to spend. 
""")
    print("What is the capital of Brazil?")
    print("1) Brazilia")
    print("2) Rio!")
    print("3) Buenos Aires!")
    
    bartender = input(prompt = "Write your response here and press enter> ")
    
    # converting using .casefold
    batender = bartender.casefold() 
    
    # loops 
    if '1' in bartender or 'Brazilia' in bartender:  
        print("""CORRECT. Go buy more beers with your gift card\n""")
       
        input(prompt = "< Press enter to continue >\n")
        stage_4()
        
    elif '3' in bartender or 'nine' in bartender: 
            print("WRONG. You need to study geography.")
            fail()
    
    elif '2' in bartender or 'Rio' in bartender:
        print("ALMOST, give it another try.")
        

        bartender = input(prompt = "Write your response here and press enter> ")
        
        # converting using .casefold
        bartender = bartender.casefold() 
            
        # extending the conditional 
        if '1' in bartender or 'Rio' in bartender: 
            print("""CORRECT. Go buy more beers with your gift card.\n""")
            stage_4()
                
        elif '3' in bartender or 'nine' in bartender: 
            print("WRONG. Time to go home.")
            fail()
            
    else: 
        print("Invalid entry")
        fail() 
        
# last stage where you have completed the previous stages and come at a last decison           
def stage_4():
    print("""
After you have spent your gift card and the bar is closing, once again your buddy 
Edwin comes inviting you keep drinking.
""")
    print("What should I do?")
    print("1) Buy another beer")
    print("2) Run away!")
    
    bar = input(prompt = "Write your response here and press enter> ")
    
    # converting using .casefold
    bar = bar.casefold() 
    
    # extending the conditional 
    if '1' in bar or 'buy' in 'bar' or 'another' in bar or 'beer' in bar:
        print("""You have kept drinking and you are problably tipsy by now. Your friend
        Edwin comes back one more and begs you to keep drinking at another bar.\n""")
       
        input(prompt = "< Press enter to continue >\n")
        stage_5()
    
    elif '2' in bar or 'run' in bar:
        print("""Go home, its most likelly you are already drunk and will not do 
        any work tonight but there is a chance tomorrow you are not hangover""")
        stage_2()   

# final 
def stage_5():
    print("""
You have completed your "NOT TO DO" journey in a middle of weekday! You are a "WINNER"!
          """)
    input("< Press enter to exit >\n")
  
# fail function 
def fail():
    print("""
                     
                     
                     <Game Over>
                            
If you don't want to continue playing type homework. 
""")
    
    play_again =  input(prompt = "< Press enter to play the game again >\n")
    
    if play_again == 'homework':
        print('End')
    
    else:
        stage_0()

stage_0()
